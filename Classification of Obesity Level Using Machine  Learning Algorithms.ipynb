# %%
import pandas as pd
data=pd.read_csv('obesity.csv')
data.head(50)
obesity_level=data['NObeyesdad'].unique()
print(obesity_level)
# Out:
# ['Normal_Weight' 'Overweight_Level_I' 'Overweight_Level_II'
#  'Obesity_Type_I' 'Insufficient_Weight' 'Obesity_Type_II'
#  'Obesity_Type_III']

# %% [markdown]
# ### Renaming columns

# %%
data=data.rename(columns={'NObeyesdad':'obesity_level'})

# %%
data
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %% [markdown]
# ## Preprocessing data
# ###  a) Checking missing values

# %%
data.isnull().sum().transpose()
# Out:
# Gender                            0
# Age                               0
# Height                            0
# Weight                            0
# family_history_with_overweight    0
# FAVC                              0
# FCVC                              0
# NCP                               0
# CAEC                              0
# SMOKE                             0
# CH2O                              0
# SCC                               0
# FAF                               0
# TUE                               0
# CALC                              0
# MTRANS                            0
# obesity_level                     0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 24

# %%
duplicates=data[data.duplicated()]
print(duplicates.count())
# Out:
# Gender                            24
# Age                               24
# Height                            24
# Weight                            24
# family_history_with_overweight    24
# FAVC                              24
# FCVC                              24
# NCP                               24
# CAEC                              24
# SMOKE                             24
# CH2O                              24
# SCC                               24
# FAF                               24
# TUE                               24
# CALC                              24
# MTRANS                            24
# obesity_level                     24
# dtype: int64

# %%
data.drop_duplicates(inplace=True)
data
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
data=data.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill='')

# %%
print(data.dtypes)
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# obesity_level                      object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
data['Gender']=LabelEncoder().fit_transform(data['Gender'])
data['family_history_with_overweight']=LabelEncoder().fit_transform(data['family_history_with_overweight'])
data['FAVC']=LabelEncoder().fit_transform(data['FAVC'])
data['CAEC']=LabelEncoder().fit_transform(data['CAEC'])
data['SMOKE']=LabelEncoder().fit_transform(data['SMOKE'])
data['SCC']=LabelEncoder().fit_transform(data['SCC'])
data['CALC']=LabelEncoder().fit_transform(data['CALC'])
data['MTRANS']=LabelEncoder().fit_transform(data['MTRANS'])
data['obesity_level']=LabelEncoder().fit_transform(data['obesity_level'])

# %%
data
# Out:
#       Gender        Age    Height      Weight  family_history_with_overweight  \
# 0          0  21.000000  1.620000   64.000000                               1
# 1          0  21.000000  1.520000   56.000000                               1
# 2          1  23.000000  1.800000   77.000000                               1
# 3          1  27.000000  1.800000   87.000000                               0
# 4          1  22.000000  1.780000   89.800000                               0
# ...      ...        ...       ...         ...                             ...
# 2082       0  20.976842  1.710730  131.408528                               1
# 2083       0  21.982942  1.748584  133.742943                               1
# 2084       0  22.524036  1.752206  133.689352                               1
# 2085       0  24.361936  1.739450  133.346641                               1
# 2086       0  23.664709  1.738836  133.472641                               1
#
# ...

# %%
X=data.iloc[:,:-1]

# %%
y=data.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state=0)

# %%
from sklearn.ensemble import RandomForestClassifier
ranclf=RandomForestClassifier(criterion="gini", max_depth=100,min_samples_split=10,random_state=10)
ranclf.fit(X_train,y_train)
ranclf.score(X_test,y_test)
# Out:
# 0.9559386973180076

# %%
import matplotlib.pyplot as plt
features=(ranclf.feature_importances_)*100
features
features=pd.DataFrame(features)
features['features_importance']=features
del features[0]
features_name=list(data.columns)
features_name.pop()
features['features']=features_name
features
# Out:
#     features_importance                        features
# 0              5.936460                          Gender
# 1              9.550036                             Age
# 2              8.727120                          Height
# 3             35.611443                          Weight
# 4              2.992861  family_history_with_overweight
# 5              1.464517                            FAVC
# 6              9.856124                            FCVC
# 7              4.956053                             NCP
# 8              3.484956                            CAEC
# 9              0.110835                           SMOKE
# 10             3.736999                            CH2O
# 11             0.543633                             SCC
# 12             3.867573                             FAF
# 13             4.696315                             TUE
# 14             2.765901                            CALC
# 15             1.699173                          MTRANS

# %%
plt.figure()
features.plot.bar(x='features',y='features_importance',figsize=(10,5),color='green')
plt.xlabel("Data_columns",fontdict=dict(size=15))
plt.ylabel("% of importance of Data_columns",fontdict=dict(size=15))
plt.title("Data_columns vs % of importance",fontdict=dict(size=15))
plt.show()

# %%
y_pred=ranclf.predict(X_test)

# %%
y_pred
# Out:
# array([3, 1, 6, 3, 2, 1, 3, 4, 1, 1, 1, 6, 6, 2, 2, 1, 5, 5, 4, 3, 5, 0,
#        6, 4, 5, 3, 2, 3, 4, 2, 2, 4, 0, 6, 1, 6, 6, 4, 3, 5, 3, 1, 6, 3,
#        2, 3, 3, 5, 3, 2, 6, 0, 4, 6, 2, 0, 1, 2, 0, 0, 6, 5, 2, 0, 6, 6,
#        2, 5, 2, 1, 5, 0, 6, 2, 5, 5, 6, 5, 0, 6, 0, 0, 4, 6, 2, 5, 4, 1,
#        6, 3, 2, 1, 2, 2, 3, 4, 1, 2, 6, 1, 2, 6, 6, 2, 5, 1, 6, 1, 5, 3,
#        2, 1, 1, 0, 6, 1, 5, 3, 4, 4, 4, 4, 3, 3, 6, 4, 3, 3, 1, 5, 5, 5,
#        3, 3, 2, 3, 6, 3, 5, 4, 4, 1, 2, 2, 4, 4, 2, 4, 2, 4, 2, 3, 5, 3,
#        3, 6, 0, 1, 0, 6, 1, 4, 0, 5, 0, 4, 1, 3, 6, 3, 4, 4, 2, 2, 1, 1,
#        2, 5, 2, 2, 4, 5, 3, 1, 2, 4, 2, 1, 2, 4, 0, 0, 4, 6, 1, 0, 0, 2,
#        1, 2, 2, 1, 1, 4, 6, 2, 6, 2, 0, 6, 1, 4, 4, 3, 4, 3, 2, 5, 3, 3,
#        6, 2, 0, 6, 1, 3, 3, 2, 2, 6, 1, 1, 5, 2, 3, 6, 2, 4, 0, 0, 2, 3,
#        4, 6, 5, 5, 3, 5, 2, 4, 4, 1, 0, 4, 3, 3, 6, 6, 4, 1, 0, 3, 2, 3,
#        6, 6, 5, 3, 4, 5, 3, 1, 2, 0, 0, 1, 4, 4, 1, 4, 0, 1, 5, 0, 0, 6,
# ...

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
# Out:
# array([[58,  2,  0,  0,  0,  0,  0],
#        [ 0, 62,  0,  0,  0,  1,  2],
#        [ 0,  0, 96,  1,  0,  0,  1],
#        [ 0,  0,  0, 80,  0,  0,  0],
#        [ 0,  0,  0,  0, 76,  0,  0],
#        [ 0,  8,  0,  0,  0, 59,  2],
#        [ 0,  3,  0,  1,  0,  2, 68]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9559386973180076

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(ranclf,X_train,y_train,cv=10)
# Out:
# array([0.94267516, 0.92356688, 0.92993631, 0.94267516, 0.91719745,
#        0.92948718, 0.96794872, 0.94871795, 0.93589744, 0.94230769])

# %%
from sklearn.metrics import classification_report
report=classification_report(y_pred,y_test,output_dict=True)
print(report)
# Out:
# {'0': {'precision': 0.9666666666666667, 'recall': 1.0, 'f1-score': 0.983050847457627, 'support': 58}, '1': {'precision': 0.9538461538461539, 'recall': 0.8266666666666667, 'f1-score': 0.8857142857142857, 'support': 75}, '2': {'precision': 0.9795918367346939, 'recall': 1.0, 'f1-score': 0.9896907216494846, 'support': 96}, '3': {'precision': 1.0, 'recall': 0.975609756097561, 'f1-score': 0.9876543209876543, 'support': 82}, '4': {'precision': 1.0, 'recall': 1.0, 'f1-score': 1.0, 'support': 76}, '5': {'precision': 0.855072463768116, 'recall': 0.9516129032258065, 'f1-score': 0.900763358778626, 'support': 62}, '6': {'precision': 0.918918918918919, 'recall': 0.9315068493150684, 'f1-score': 0.9251700680272108, 'support': 73}, 'accuracy': 0.9559386973180076, 'macro avg': {'precision': 0.9534422914192213, 'recall': 0.9550565964721576, 'f1-score': 0.9531490860878413, 'support': 522}, 'weighted avg': {'precision': 0.9573592305869025, 'recall': 0.9559386973180076, 'f1-score': 0.9556096310166918, 'su
# ...

# %%
each=pd.DataFrame(report).transpose()
new_report=each.drop([each.index[7],each.index[8],each.index[9]])
new_report
# Out:
#    precision    recall  f1-score  support
# 0   0.966667  1.000000  0.983051     58.0
# 1   0.953846  0.826667  0.885714     75.0
# 2   0.979592  1.000000  0.989691     96.0
# 3   1.000000  0.975610  0.987654     82.0
# 4   1.000000  1.000000  1.000000     76.0
# 5   0.855072  0.951613  0.900763     62.0
# 6   0.918919  0.931507  0.925170     73.0

# %%
names=['Insufficient_Weight','Normal_Weight','Obesity_Type_I','Obesity_Type_II','Obesity_Type_III','Overweight_Level_I',
       'Overweight_Level_II']
new_report['obesity_level']=names
new_report['precision']=new_report['precision']*100
new_report
# Out:
#     precision    recall  f1-score  support        obesity_level
# 0   96.666667  1.000000  0.983051     58.0  Insufficient_Weight
# 1   95.384615  0.826667  0.885714     75.0        Normal_Weight
# 2   97.959184  1.000000  0.989691     96.0       Obesity_Type_I
# 3  100.000000  0.975610  0.987654     82.0      Obesity_Type_II
# 4  100.000000  1.000000  1.000000     76.0     Obesity_Type_III
# 5   85.507246  0.951613  0.900763     62.0   Overweight_Level_I
# 6   91.891892  0.931507  0.925170     73.0  Overweight_Level_II

# %%
plt.figure()
new_report.plot.bar(x='obesity_level',y='precision',color='green',figsize=(10,5),rot=75)
plt.xlabel("obesity level",fontdict=dict(size=15))
plt.ylabel("% of Classifiaction accuracy",fontdict=dict(size=15))
plt.title("obesity vs % of Classification accuracy",fontdict=dict(size=15))
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
modeltree=DecisionTreeClassifier(max_leaf_nodes=8)
modeltree.fit(X_train,y_train)
modeltree.score(X_test,y_test)
# Out:
# 0.710727969348659

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
names = ["insufficient","normal weight","obesity typeI","obesity type II","obesity type III","overweight level 1","overweight level 2"]

plt.figure(figsize=(20,10))
plot_tree(modeltree, feature_names = X.columns,class_names=names,rounded = True, filled= True)
plt.show()

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB().fit(X_train,y_train)
gnb.score(X_test,y_test)
# Out:
# 0.5977011494252874

# %%
gnb_pred=gnb.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,gnb_pred)
# Out:
# 0.5977011494252874
